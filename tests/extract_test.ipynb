# %%
# !where python
# Out:
# c:\Users\Henrique Hashimoto\Desktop\repos\automated_finances\.venv\Scripts\python.exe
# C:\Users\Henrique Hashimoto\.pyenv\pyenv-win\shims\python
# C:\Users\Henrique Hashimoto\.pyenv\pyenv-win\shims\python.bat
# C:\Users\Henrique Hashimoto\AppData\Local\Programs\Python\Python312\python.exe

# %%
import pandas as pd

# %%
df = pd.read_excel("../data/export-transactions_20250207.xlsx", skiprows=4)
df = df.iloc[:, 1:]
df.head(10)
# Out:
#          Data           Título    Categoria                Conta  \
# 0  02/12/2024     13o salário         renda  Keth Conta e Debito
# 1  03/12/2024            iFood  alimentação  Keth Conta e Debito
# 2  03/12/2024           Faxina      moradia  Keth Conta e Debito
# 3  04/12/2024    a identificar       outros  Keth Conta e Debito
# 4  04/12/2024             café  alimentação  Keth Conta e Debito
# 5  05/12/2024            cafe   alimentação  Keth Conta e Debito
# 6  06/12/2024               99   transporte  Keth Conta e Debito
# 7  09/12/2024     restaurante   alimentação  Keth Conta e Debito
# 8  09/12/2024               99   transporte  Keth Conta e Debito
# 9  09/12/2024  estacionamento    transporte  Keth Conta e Debito
#
#   Cartão de crédito    Valor
# 0               NaN  2451.02
# 1               NaN   -38.98
# 2               NaN  -250.00
# 3               NaN   -95.90
# 4               NaN   -12.49
# 5               NaN   -13.50
# 6               NaN   -49.20
# ...
